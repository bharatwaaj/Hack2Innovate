# %% [markdown]
# Analysis of Market Tensions due to Global News
# ------------
#
# This is the analysis of the stock market S&P BSE Index based on the tweeets owing to International Stocks Falling down,
# War between countries or other sensational news.

# %%
# Imports
import re
import tweepy
from tweepy import OAuthHandler
from textblob import TextBlob
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt2
import sys
import pandas as pd
from dateutil import parser
from datetime import datetime, timedelta

# %%
# Twitter Client Class    
class TwitterClient(object):
    
    def __init__(self):
        # keys and tokens from the Twitter Dev Console
        consumer_key = 'Ve8tKh7aP2CtGhFUtV26W7Zr8'
        consumer_secret = 'P7L9hsifW5cRT4Yg9eJHzDtmi1RZ42ENSWwcKLp7SkegoG4TYT'
        access_token = '2918675084-KoiDatN9UJnvOKJxv4E2eFXmbh94GTiydawSf9w'
        access_token_secret = 'xpcA5NEFyGZ6WQZ5leXpBqHJDS8DlBBseQGqJpJQJU6Y9'
 
        # attempt authentication
        try:
            # create OAuthHandler object
            self.auth = OAuthHandler(consumer_key, consumer_secret)
            # set access token and secret
            self.auth.set_access_token(access_token, access_token_secret)
            # create tweepy API object to fetch tweets
            self.api = tweepy.API(self.auth)
        except:
            print("Error: Authentication Failed")
 
    def clean_tweet(self, tweet):
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())
 
    def get_tweet_sentiment(self, tweet):
        # create TextBlob object of passed tweet text
        analysis = TextBlob(self.clean_tweet(tweet))
        # set sentiment
        if analysis.sentiment.polarity > 0:
            return 'positive'
        elif analysis.sentiment.polarity == 0:
            return 'neutral'
        else:
            return 'negative'
 
    def get_tweets(self, query, count = 10):
        '''
        Main function to fetch tweets and parse them.
        '''
        # empty list to store parsed tweets
        tweets = []
 
        try:
            # call twitter api to fetch tweets
            fetched_tweets = self.api.search(q = query, since="2017-11-07",
                           until="2017-11-10", count = count)
 
            # parsing tweets one by one
            for tweet in fetched_tweets:
                # empty dictionary to store required params of a tweet
                parsed_tweet = {}
 
                # saving text of tweet
                parsed_tweet['tweet'] = tweet.text
                # saving sentiment of tweet
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text)
                # saving time of tweet
                parsed_tweet['created_at'] = tweet.created_at
                # saving user location
                parsed_tweet['user_location'] = tweet.user.location
 
                # appending parsed tweet to tweets list
                if tweet.retweet_count > 0:
                    # if tweet has retweets, ensure that it is appended only once
                    if parsed_tweet not in tweets:
                        tweets.append(parsed_tweet)
                else:
                    tweets.append(parsed_tweet)
 
            # return parsed tweets
            return tweets
 
        except tweepy.TweepError as e:
            # print error (if any)
            print("Error : " + str(e))

# %%
# creating object of TwitterClient Class
api = TwitterClient()
# calling function to get tweets
queries = ['War', 'Market Down', 'Nasdaq down', 'Dow Jones down', 'Red Market', 'Bleeding Market']
epoch = 100

tweets = []

for query in queries:
    tweetlist = api.get_tweets(query = query, count = epoch)
    tweets.extend(tweetlist)
    
tweets_df = pd.DataFrame(tweets)

# %%
tweets_df.to_csv('StockVibes.csv')

# %%
tweets_df.head()
# Out:
#            created_at sentiment  \
# 0 2017-11-09 23:59:59   neutral
# 2017-11-10 02:30:00    2017-11-10
# 2017-11-10 02:45:00    2017-11-10
# 2017-11-10 03:00:00    2017-11-10
# 2017-11-10 03:15:00    2017-11-10
# 2017-11-10 03:30:00    2017-11-10
# 2017-11-10 03:45:00    2017-11-10
# 2017-11-10 04:00:00    2017-11-10
# 2017-11-10 04:15:00    2017-11-10
# 2017-11-10 04:30:00    2017-11-10
# 2017-11-10 04:45:00    2017-11-10
# 2017-11-10 05:00:00    2017-11-10
# Name: Date, Length: 230, dtype: object

# %%
# Time Conversion
def ceil_dt(dt):
    delta = timedelta(minutes=15)
    return (dt + (datetime.min - dt) % delta) + timedelta(hours=2)

# %%
stock_date = []
for index, row in stock_data.iterrows():
    stock_date.append(parser.parse(index))
se = pd.Series(stock_date)
stock_data['Time'] = se.values

tweets_df_date = []
for index, row in tweets_df.iterrows():
    tweets_df_date.append(row[0])
se = pd.Series(tweets_df_date)
tweets_df['Act_Time'] = se.values
tweets_df['Time'] = se.values

# %%
stock_date = []
for index, row in stock_data.iterrows():
    stock_date.append(parser.parse(index).date())
se = pd.Series(stock_date)
stock_data['Date'] = se.values

# %%
tweets_df.head()
# Out:
#            created_at sentiment  \
# 0 2017-11-09 23:59:59   neutral
# 1 2017-11-09 23:59:59   neutral
# 2 2017-11-09 23:59:59  positive
# 3 2017-11-09 23:59:59  negative
# 4 2017-11-09 23:59:58  positive
#
#                                                tweet         user_location  \
# 0  RT @runawayj1m: @EastNash10 @BernieUpstateNY @...         San Diego, CA
# 1  RT @cynthiamckinney: South Koreans don't want ...
# 2  RT @CloydRivers: When you’re Back to Back Worl...  somewhere in the usa
# 3  RT @MooreSenate: I believe you and I have a du...      Washington, D.C.
# 4  @WrestleCircus Home in New Mexico with @Wrestl...
#
#              Act_Time                Time
# 0 2017-11-09 23:59:59 2017-11-09 23:59:59
# 1 2017-11-09 23:59:59 2017-11-09 23:59:59
# 2 2017-11-09 23:59:59 2017-11-09 23:59:59
# 3 2017-11-09 23:59:59 2017-11-09 23:59:59
# 4 2017-11-09 23:59:58 2017-11-09 23:59:58

# %%
new_time = []
for index, row in tweets_df.iterrows():
    new_time.append(ceil_dt(parser.parse(str(row[4]))))
se = pd.Series(new_time)
tweets_df['Time'] = se.values

# %%
new_df = pd.merge(tweets_df, stock_data, on='Time')

# %%
new_df.head()
# Out:
#            created_at sentiment  \
# 0 2017-11-09 23:59:59   neutral
# 1 2017-11-09 23:59:59   neutral
# 2 2017-11-09 23:59:59  positive
# 3 2017-11-09 23:59:59  negative
# 4 2017-11-09 23:59:58  positive
#
#                                                tweet         user_location  \
# 0  RT @runawayj1m: @EastNash10 @BernieUpstateNY @...         San Diego, CA
# 1  RT @cynthiamckinney: South Koreans don't want ...
# 2  RT @CloydRivers: When you’re Back to Back Worl...  somewhere in the usa
# 3  RT @MooreSenate: I believe you and I have a du...      Washington, D.C.
# 4  @WrestleCircus Home in New Mexico with @Wrestl...
#
#              Act_Time                Time      open      high       low  \
# 0 2017-11-09 23:59:59 2017-11-10 02:00:00  33212.58  33213.37  33178.99
# 1 2017-11-09 23:59:59 2017-11-10 02:00:00  33212.58  33213.37  33178.99
# 2 2017-11-09 23:59:59 2017-11-10 02:00:00  33212.58  33213.37  33178.99
# 3 2017-11-09 23:59:59 2017-11-10 02:00:00  33212.58  33213.37  33178.99
# 4 2017-11-09 23:59:58 2017-11-10 02:00:00  33212.58  33213.37  33178.99
#
#       close  volume        Date
# 0  33180.11     0.0  2017-11-10
# 1  33180.11     0.0  2017-11-10
# 2  33180.11     0.0  2017-11-10
# 3  33180.11     0.0  2017-11-10
# 4  33180.11     0.0  2017-11-10

# %%
ptlist = []
phlist = []
pclist = []
ntlist = []
nhlist = []
nclist = []
for index, row in new_df.iterrows():
    if row[1] == 'positive':
        phlist.append(row[7])
        pclist.append(row[9])
        ptlist.append((row[5]).time())
    if row[1] == 'negative':
        nhlist.append(row[7])
        nclist.append(row[9])
        ntlist.append((row[5]).time())

# %%
# %matplotlib inline

plt.figure(figsize = (12,6))
plt.plot(ptlist,phlist,ptlist,pclist)
plt.ylabel('Close and High Prices')
plt.xlabel('Time')
plt.title('Positive')
plt.show()

# %%
plt2.figure(figsize = (12,6))
plt2.plot(ntlist,nhlist,ntlist,nclist)
plt2.ylabel('Close and High Prices')
plt2.xlabel('Time')
plt2.title('Negative')
plt2.show()

# %%
temp_df = new_df
new_temp_df = temp_df
p_new_temp_df = new_temp_df[new_temp_df['sentiment'] == 'positive' && ]
p_new_temp_df = p_new_temp_df.sort_values(['Time'])
p_new_temp_df = p_new_temp_df.drop_duplicates(subset = 'Time',keep=False)
n_new_temp_df = new_temp_df[new_temp_df['sentiment'] == 'negative']
n_new_temp_df = n_new_temp_df.sort_values(['Time'])
n_new_temp_df = n_new_temp_df.drop_duplicates(subset = 'Time',keep=False)
plt.plot(p_new_temp_df['Time'], p_new_temp_df['high'], p_new_temp_df['Time'], p_new_temp_df['close'])
# Out:
# [<matplotlib.lines.Line2D at 0x2446a494080>,
#  <matplotlib.lines.Line2D at 0x2446a4ca0b8>]

# %%
new_temp_df
# Out:
#              created_at sentiment  \
# 0   2017-11-09 23:59:59   neutral
# 1   2017-11-09 23:59:59   neutral
# 2   2017-11-09 23:59:59  positive
# 3   2017-11-09 23:59:59  negative
# 4   2017-11-09 23:59:58  positive
# 5   2017-11-09 23:59:58   neutral
# 6   2017-11-09 23:59:57  positive
# 7   2017-11-09 23:59:57  negative
# 8   2017-11-09 23:59:57  positive
# 9   2017-11-09 23:59:57   neutral
# 10  2017-11-09 23:59:55  negative
# 11  2017-11-09 23:59:55   neutral
# 12  2017-11-09 23:59:53   neutral
# 13  2017-11-09 23:59:53  negative
# 14  2017-11-09 23:59:53   neutral
# 15  2017-11-09 23:59:52  negative
# 16  2017-11-09 23:59:51   neutral
# 17  2017-11-09 23:59:51  negative
# 18  2017-11-09 23:59:51  negative
# 19  2017-11-09 23:59:51  negative
# 20  2017-11-09 23:59:50   neutral
# 21  2017-11-09 23:59:50  positive
# 245  33178.13  33206.87  33177.04  33202.42     0.0  2017-11-09
# 246  33178.13  33206.87  33177.04  33202.42     0.0  2017-11-09
# 247  33178.13  33206.87  33177.04  33202.42     0.0  2017-11-09
# 248  33178.13  33206.87  33177.04  33202.42     0.0  2017-11-09
# 249  33178.13  33206.87  33177.04  33202.42     0.0  2017-11-09
# 250  33266.30  33269.13  33240.64  33266.53     0.0  2017-11-10
# 251  33266.30  33269.13  33240.64  33266.53     0.0  2017-11-10
# 252  33266.30  33269.13  33240.64  33266.53     0.0  2017-11-10
# 253  33193.68  33201.63  33160.51  33178.57     0.0  2017-11-09
# 254  33193.68  33201.63  33160.51  33178.57     0.0  2017-11-09
# 255  33193.68  33201.63  33160.51  33178.57     0.0  2017-11-09
# 256  33193.68  33201.63  33160.51  33178.57     0.0  2017-11-09
# 257  33193.68  33201.63  33160.51  33178.57     0.0  2017-11-09
# 258  33193.68  33201.63  33160.51  33178.57     0.0  2017-11-09
# 259  33193.68  33201.63  33160.51  33178.57     0.0  2017-11-09
# 260  33263.89  33285.66  33252.32  33253.20     0.0  2017-11-09
# 261  33266.06  33270.14  33250.18  33262.18     0.0  2017-11-10
# 262  33266.06  33270.14  33250.18  33262.18     0.0  2017-11-10
# 263  33266.06  33270.14  33250.18  33262.18     0.0  2017-11-10
# 264  33266.06  33270.14  33250.18  33262.18     0.0  2017-11-10
# 265  33266.06  33270.14  33250.18  33262.18     0.0  2017-11-10
# 266  33266.06  33270.14  33250.18  33262.18     0.0  2017-11-10
# 267  33246.44  33280.30  33246.44  33266.99     0.0  2017-11-10
# 268  33246.44  33280.30  33246.44  33266.99     0.0  2017-11-10
# 269  33246.44  33280.30  33246.44  33266.99     0.0  2017-11-10
# 270  33380.90  33382.37  33353.55  33359.79     0.0  2017-11-08
# 271  33447.52  33458.75  33369.32  33381.22     0.0  2017-11-07
#
# [272 rows x 12 columns]

# %%
plt.plot(n_new_temp_df['Time'], n_new_temp_df['high'], n_new_temp_df['Time'], n_new_temp_df['close'])
# Out:
# [<matplotlib.lines.Line2D at 0x24469fb14a8>,
#  <matplotlib.lines.Line2D at 0x2446a560a90>]

# %%
ptlist = []
phlist = []
pclist = []
ntlist = []
nhlist = []
nclist = []
for index, row in p_new_temp_df.iterrows():
        phlist.append(row[7])
        pclist.append(row[9])
        ptlist.append((row[5]).time())
for index, row in n_new_temp_df.iterrows():        
        nhlist.append(row[7])
        nclist.append(row[9])
        ntlist.append((row[5]).time())

# %%
ptlist
# Out:
# [datetime.time(23, 30),
#  datetime.time(2, 45),
#  datetime.time(1, 30),
#  datetime.time(23, 30),
#  datetime.time(0, 45)]

# %%
# %matplotlib inline

plt.figure(figsize = (12,6))
plt.plot(ptlist,phlist,ptlist,pclist)
plt.ylabel('Close and High Prices')
plt.xlabel('Time')
plt.title('Positive')
plt.show()

# %%
plt2.figure(figsize = (12,6))
plt2.plot(ntlist,nhlist,ntlist,nclist)
plt2.ylabel('Close and High Prices')
plt2.xlabel('Time')
plt2.title('Negative')
plt2.show()
